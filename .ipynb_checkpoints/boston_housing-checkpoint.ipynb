# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import LinearSVR
from sklearn.datasets import load_boston

# %%
# Загружаем датасет
boston = load_boston()
# Out:
# /Users/mseastar/.brew/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
# ...

# %%
# Преобразовываем данные в датафрейм
df = pd.DataFrame(boston.data, columns=boston.feature_names)
df['MEDV'] = boston.target

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
# Выводим строки с пропущенными значениями
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []

# %%
sns.heatmap(df.corr().abs()[['MEDV']], cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
# Посмотрим коррелцию между фичами
corr = df.corr()
plt.figure(figsize=(20,20))
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool)) 
sns.heatmap(corr,mask=mask, annot=True, cmap='Greens', fmt='.1f')
# Out:
# /var/folders/zz/zyxvpxvq6csfxvn_n003vq4000yxs0/T/ipykernel_27832/3268746802.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
# <AxesSubplot:>

# %%
X = df[['INDUS', 'RM', 'TAX', 'PTRATIO', 'LSTAT']]

y = df.MEDV

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=4)

# %%
from sklearn.decomposition import PCA

# %%
X

# %%
pca = PCA()

# %%
pca.fit_transform(X_train)

# %% [markdown]
# #  Linear regression

# %%
lm = LinearRegression().fit(X_train, y_train)

# %%
coefs_lm = pd.DataFrame([i for i in zip(X_train.columns, lm.coef_)]).rename(columns={0: 'Feature', 1: 'Coef'})

# %%
coefs_lm
# Out:
#    Feature      Coef
# 0    INDUS  0.044654
# 1       RM  4.371127
# 2      TAX -0.002670
# 3  PTRATIO -0.779218
# 4    LSTAT -0.557779

# %%
y_pred = lm.predict(X_train)

# %%
lm.score(X_train, y_train)
# Out:
# 0.6662572158425879

# %%
model_1 = lm.score(X_test, y_test)
print(f'R^2 {metrics.r2_score(y_train, y_pred)}')
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train) - X_train.shape[1] - 1))
print('MAE', metrics.mean_absolute_error(y_train, y_pred))
print('MSE', metrics.mean_squared_error(y_train, y_pred))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# R^2 0.6662572158425879
# Adjusted R^2: 0.6614620608977975
# MAE 3.519980386890112
# MSE 25.121096257438754
# RMSE 5.012094996848997

# %% [markdown]
# 𝑅^2 : It is a measure of the linear relationship between X and Y. It is interpreted as the proportion of the variance in the dependent variable that is predictable from the independent variable.
#
# Adjusted 𝑅^2 :The adjusted R-squared compares the explanatory power of regression models that contain different numbers of predictors.
#
# MAE : It is the mean of the absolute value of the errors. It measures the difference between two continuous variables, here actual and predicted values of y.
#
# MSE: The mean square error (MSE) is just like the MAE, but squares the difference before summing them all instead of using the absolute value.
#
# RMSE: The mean square error (MSE) is just like the MAE, but squares the difference before summing them all instead of using the absolute value.

# %%
sns.scatterplot(x=y_train, y=y_pred)
plt.xlabel('y train')
plt.ylabel('y test')
# Out:
# Text(0, 0.5, 'y test')

# %% [markdown]
# # Чекаем остатки

# %%
sns.scatterplot(y_train, y_train - y_pred)
# Out:
# /Users/mseastar/.brew/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MEDV', ylabel='MEDV'>

# %% [markdown]
# ### В основном остатки скопились вокруг нуля. Что говорит нам что преположение о линейной зависимости подтвердилось!

# %% [markdown]
# ### Проверим остатки на нормальность

# %%
g = sns.histplot(y_train - y_pred, kde='line')
g.set_xlabel('Остатки')
g.set_ylabel('Частота')
plt.show()

# %% [markdown]
# Остатки нормально распределены!

# %%
rg = RandomForestRegressor().fit(X_train, y_train)

# %%
y_pred = rg.predict(X_train)

# %%
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# R^2: 0.9708419696148478
# Adjusted R^2: 0.9704230323966704
# MAE: 0.9779745762711854
# MSE: 2.194749138418079
# RMSE: 1.4814685749006218

# %%
sns.scatterplot(x=y_train, y=y_pred)
# Out:
# <AxesSubplot:xlabel='MEDV'>

# %%
sns.scatterplot(x=y_train, y=y_train - y_pred)
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='MEDV'>

# %%
sns.histplot(y_train - y_pred, kde='line')
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='Count'>

# %%
y_test_pred = rg.predict(X_test)

# %%
model_2 = metrics.r2_score(y_test, y_test_pred)
print('R^2:', acc_rf)
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# R^2: 0.8156996618463086
# Adjusted R^2: 0.8116529914648314
# MAE: 2.696223684210527
# MSE: 19.01597618421054
# RMSE: 4.360731152480113

# %%
from xgboost import XGBRegressor

# %%
xgb = XGBRegressor().fit(X_train, y_train)

# %%
y_pred = xgb.predict(X_train)

# %%
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# R^2: 0.9998338667822311
# Adjusted R^2: 0.9998314798107114
# MAE: 0.07478963049118124
# MSE: 0.012504985135989365
# RMSE: 0.11182569085853825

# %%
sns.scatterplot(x=y_train, y=y_pred)
# Out:
# <AxesSubplot:xlabel='MEDV'>

# %%
sns.scatterplot(y_train,y_train - y_pred)
# Out:
# /Users/mseastar/.brew/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MEDV', ylabel='MEDV'>

# %%
sns.histplot(y_train - y_pred)
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='Count'>

# %%
y_test_pred = xgb.predict(X_test)

# %%
model_3 = metrics.r2_score(y_test, y_test_pred)
print('R^2:', acc_xgb)
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# R^2: 0.8424732302736423
# Adjusted R^2: 0.8370784778857534
# MAE: 2.789564261310979
# MSE: 16.44895668115355
# RMSE: 4.0557313373981705

# %%
svr = LinearSVR(verbose=True, max_iter=10000).fit(X_train, y_train)
# Out:
# [LibLinear]...........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# ...

# %%
y_pred = svr.predict(X_train)

# %%
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# R^2: 0.6335413128423061
# Adjusted R^2: 0.6282761018199254
# MAE: 3.661241591502561
# MSE: 27.583649419431534
# RMSE: 5.252013844177444

# %%
sns.scatterplot(y_train, y_pred)
# Out:
# /Users/mseastar/.brew/Cellar/jupyterlab/3.4.3/libexec/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MEDV'>

# %%
sns.histplot(y_train - y_pred)
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='Count'>

# %%
y_test_pred = svr.predict(X_test)

# %%
model_4 = metrics.r2_score(y_test, y_test_pred)
print('R^2:', metrics.r2_score(y_test, y_test_pred))
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# R^2: 0.6770513011626127
# Adjusted R^2: 0.6659914142161268
# MAE: 3.916272388506427
# MSE: 33.72232647593132
# RMSE: 5.807092773146587

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
scores_df
# Out:
#      model                    score
# 0  LinearR   [0.695267039139429, 0]
# 1   Random   [0.817889647376592, 1]
# 2  XgBoost  [0.8424732302736423, 2]
# 3      SVM  [0.6770513011626127, 3]

# %%
np.diag([3, 3])
# Out:
# array([[3, 0],
#        [0, 3]])
