# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
train_df = pd.read_csv('archive/train.csv')
train_df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
pd.DataFrame({k : [v] for k, v in train_df.isna().sum().items() if v > 0})
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
train_df.price_range.unique()
# Out:
# array([1, 2, 3, 0])

# %%
# без зависимой переменной
test_df = pd.read_csv('archive/test.csv')

# %%
test_df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
pd.DataFrame({k : [v] for k, v in test_df.isna().sum().items() if v > 0})
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
mask = np.triu(np.ones_like(train_df.corr().abs(), dtype=bool))

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(train_df.corr().abs(), mask=mask, annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression

# %%
X = train_df.drop('price_range', axis=1)

# %%
y = train_df.price_range

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
ln = LinearRegression().fit(X_train, y_train)

# %%
models_score = pd.DataFrame(columns=['model', 'train_score', 'test_score'])

# %%
models_score
# Out:
# Empty DataFrame
# Columns: [model, train_score, test_score]
# Index: []

# %%
models_score = pd.concat([models_score, pd.Series({'Lineal regression': ln.score(X_test, y_test)})])

# %%
models_score
# Out:
#                   model train_score test_score         0
# Lineal regression   NaN         NaN        NaN  0.919296
